# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhozgu/Boilerplate/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import utils
import llm

print("Modules utils et llm importés avec succès.")
# Out:
# Modules utils et llm importés avec succès.

# %%
# Installez ces bibliothèques si elles ne sont pas déjà installées
# !pip install sentence-transformers torch

# %%
# Les modules 'llm' et 'utils' sont déjà importés depuis vos fichiers locaux.
# from ca_llm import ... devient from llm import ...

from sentence_transformers import SentenceTransformer
from torch import utils  # Ceci importe le module 'utils' de la bibliothèque torch

# Importe les fonctions spécifiques du module 'llm'
from llm import load_index, load_metadata
from llm import load_llm, generate_answer

print("Toutes les importations et fonctions spécifiées ont été traitées.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-3853063462.py in <cell line: 0>()
#       6
#       7 # Importe les fonctions spécifiques du module 'llm'
# ----> 8 from llm import load_index, load_metadata
#       9 from llm import load_llm, generate_answer
#      10
#
# ImportError: cannot import name 'load_index' from 'llm' (/content/llm.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
